# %%
################## IMPORT ######################
import json
from datetime import datetime
from functools import partial, wraps

import fire
import jax
import jax.numpy as jnp
import numpy as np
from jax import jit, random, value_and_grad, vmap
# from jax.experimental import optimizers
from jax.example_libraries import optimizers
from jax_md import space
from shadow.plot import *
from sklearn.metrics import r2_score
from psystems.nsprings import (chain, edge_order, get_connections,
                               get_fully_connected_senders_and_receivers,
                               get_fully_edge_order)
# from statistics import mode
# from sympy import LM
# from torch import batch_norm_gather_stats_with_counts
import sys
MAINPATH = ".."  # nopep8
sys.path.append(MAINPATH)  # nopep8
import jraph
import src
from jax.config import config
# from src import fgn, lnn
from src.graph import *
# from src.lnn import acceleration, accelerationFull, accelerationTV
from src.md import *
from src.models import MSE, initialize_mlp, GaussianNLL, initialize_mlp_gamma, forward_pass_gamma
from src.nve import NVEStates, nve, BrownianStates
from src.utils import *

# config.update("jax_enable_x64", True)
# config.update("jax_debug_nans", True)
# jax.config.update('jax_platform_name', 'gpu')

def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]


def pprint(*args, namespace=globals()):
    for arg in args:
        print(f"{namestr(arg, namespace)[0]}: {arg}")

f32 = jnp.float32
f64 = jnp.float64

# %%
N = 5  # number of particles
dim = 2  # dimensions
runs = 1
kT = 1 #1.380649e-23*T  # boltzmann constant*temperature
# spring_constant = 1.0
# length_constant = 1.0
# nconfig=100
seed=42
dt = 1.0e-3 # time step*stride 
lr=1e-4
batch_size=20
epochs = 10000
# node_type = jnp.array([0,0,0,0,0])
masses = jnp.ones(N)
species = jnp.zeros(N, dtype=int).reshape(-1,1)
# gamma = jnp.ones(jnp.unique(species).shape)  # damping constant

rname=True
withdata = None

print("Configs: ")
pprint(N, epochs, seed, rname, dt, lr, batch_size, namespace=locals())

randfilename = datetime.now().strftime("%m-%d-%Y_%H-%M-%S")

PSYS = f"a-{N}-Spring-data-brownian_EM"
TAG = f"3BFGN"
out_dir = f"../results"

def _filename(name, tag=TAG):
    rstring = randfilename if (rname and (tag != "data")) else (
        "0" if (tag == "data") or (withdata == None) else f"0_{withdata}")
    filename_prefix = f"{out_dir}/{PSYS}-{tag}/{rstring}/"
    file = f"{filename_prefix}/{name}"
    os.makedirs(os.path.dirname(file), exist_ok=True)
    filename = f"{filename_prefix}/{name}".replace("//", "/")
    print("===", filename, "===")
    return filename

def displacement(a, b):
    return a - b

def shift(R, dR):
    return R+dR

def OUT(f):
    @wraps(f)
    def func(file, *args, tag=TAG, **kwargs):
        return f(_filename(file, tag=tag), *args, **kwargs)
    return func

loadmodel = OUT(src.models.loadmodel)
savemodel = OUT(src.models.savemodel)

loadfile = OUT(src.io.loadfile)
savefile = OUT(src.io.savefile)
save_ovito = OUT(src.io.save_ovito)
# Out:
# Configs:
# N: 5
# epochs: 10000
# seed: 42
# rname: True
# dt: 0.001
# lr: 0.0001
# batch_size: 20

# %%
################################################
################## CONFIG ######################
################################################
np.random.seed(seed)
key = random.PRNGKey(seed)

try:
    dataset_states = loadfile(f"model_states_brownian.pkl", tag="data")[0]
except:
    raise Exception("Generate dataset first.")

model_states = dataset_states[0]

print(f"Total number of data points: {len(dataset_states)}x{model_states.position.shape[0]}")

Rs = States_Brow().fromlist(dataset_states).get_array()

Rs_in = Rs[:,:99,:,:]
Rs_out = Rs[:,1:100,:,:]
# Out:
# === ../results/a-5-Spring-data-brownian_EM-data/0/model_states_brownian.pkl ===
# Total number of data points: 100x100

# %%
from functools import partial

import haiku as hk
import jax
import jax.numpy as jnp
import numpy as np
from jax import grad, jit, lax, random
from jax_md.nn import GraphNetEncoder
from jraph import GraphMapFeatures, GraphNetwork, GraphsTuple

from src.models import SquarePlus, forward_pass, initialize_mlp


class GraphEncodeNet():
    def __init__(self, N, embedding_fn, model_fn, final_fn):
        self.N = N
        self._encoder = GraphMapFeatures(
            embedding_fn('EdgeEncoder'),
            embedding_fn('NodeEncoder'),
            embedding_fn('GlobalEncoder'))
        self._propagation_network = GraphNetwork(
            model_fn('EdgeFunction'),
            model_fn('NodeFunction'),
            model_fn('GlobalFunction'), aggregate_edges_for_globals_fn=lambda *x: jnp.array([0.0]))
        self._final = GraphNetwork(
            final_fn('EdgeFunction'),
            final_fn('NodeFunction'),
            final_fn('GlobalFunction'), aggregate_edges_for_globals_fn=lambda *x: jnp.array([0.0]))

    def __call__(self, graph):
        output = self._encoder(graph)
        for _ in range(self.N):
            output = self._propagation_network(output)
        output = self._final(output)
        return output


def cal(params, graph, mpass=1):
    ee_params = params["ee_params"]
    ne_params = params["ne_params"]
    e_params = params["e_params"]
    n_params = params["n_params"]
    g_params = params["g_params"]

    def node_em(nodes):
        out = jnp.hstack([v for k, v in nodes.items()])
        def fn(out):
            return forward_pass(ne_params, out, activation_fn=SquarePlus)
        out = jax.vmap(fn)(out)
        return {"embed": out}
    
    def edge_em(edges):
        out = edges["dij"]
        out = jax.vmap(lambda p, x: forward_pass(p, x.reshape(-1)),
                       in_axes=(None, 0))(ee_params, out)
        return {"embed": out}

    embedding = {
        "EdgeEncoder": edge_em,
        "NodeEncoder": node_em,
        "GlobalEncoder": None,
    }
    
    def embedding_fn(arg): return embedding[arg]

    def edge_fn(edges, sent_attributes, received_attributes, global_):
        out = jnp.hstack([edges["embed"], sent_attributes["embed"],
                          received_attributes["embed"]])
        out = jax.vmap(forward_pass, in_axes=(None, 0))(e_params, out)
        return {"embed": out}

    def node_fn(nodes, sent_attributes, received_attributes, global_):
        out = jnp.hstack([nodes["embed"], sent_attributes["embed"],
                          received_attributes["embed"]])
        out = jax.vmap(forward_pass, in_axes=(None, 0))(n_params, out)
        return {"embed": out}

    model = {
        "EdgeFunction": edge_fn,
        "NodeFunction": node_fn,
        "GlobalFunction": None,
    }

    def model_fn(arg): return model[arg]

    final = {
        "EdgeFunction": lambda *x: x[0],
        "NodeFunction": lambda *x: x[0],
        "GlobalFunction": lambda node_attributes, edge_attribtutes, globals_:
        forward_pass(g_params, node_attributes["embed"].reshape(-1)),
        # "GlobalFunction": lambda node_attributes, edge_attribtutes, globals_:
        #     node_attributes["embed"].sum()
    }

    def final_fn(arg): return final[arg]

    net = GraphEncodeNet(mpass, embedding_fn, model_fn, final_fn)
    
    graph = net(graph)

    return graph


def cal_energy(params, graph, **kwargs):
    graph = cal(params, graph, **kwargs)
    return graph.globals.sum()


def cal_acceleration(params, graph, **kwargs):
    graph = cal(params, graph, **kwargs)
    acc_params = params["acc_params"]
    out = jax.vmap(forward_pass, in_axes=(None, 0))(acc_params, graph.nodes["embed"])
    return out

def acceleration_node(R,V, params, **kwargs):
    inp = jnp.hstack([R.flatten(),V.flatten()])
    out = jax.vmap(forward_pass, in_axes=(None, 0))(params, inp)
    return out

# %%
# state_graph = jraph.GraphsTuple(nodes={
#     "position": R,
#     "type": species
# },
#     edges={"dij": dij},
#     senders=senders,
#     receivers=receivers,
#     n_node=jnp.array([R.shape[0]]),
#     n_edge=jnp.array([senders.shape[0]]),
#     globals={})

# %%
# graph = cal(params['F_pos'], state_graph)

# %%
################################################
################### ML Model ###################
################################################
# print("Creating Chain")
x, _, senders, receivers = chain(N)

hidden_dim = [16, 16]
edgesize = 1 # |dij|
nodesize = 2+1 # 2pos,1type
ee = 8
ne = 8
Fparams = dict(
    ee_params=initialize_mlp([edgesize, ee], key),
    ne_params=initialize_mlp([nodesize, ne], key),
    e_params=initialize_mlp([ee+2*ne, *hidden_dim, ee], key),
    n_params=initialize_mlp([2*ee+ne, *hidden_dim, ne], key),
    g_params=initialize_mlp([ne, *hidden_dim, 1], key),
    acc_params=initialize_mlp([ne, *hidden_dim, dim], key),
)
params = {"F_pos": Fparams}

# %%
params["gamma"] = initialize_mlp_gamma([1,10,5,1], key)

def nngamma(type, params):
    return forward_pass_gamma(params, type, activation_fn=models.SquarePlus)

def gamma(type, params):
    return vmap(nngamma, in_axes=(0, None))(type.reshape(-1), params).reshape(-1, 1)
    # return nngamma(type.reshape(-1), params["gamma"])#.reshape(-1, 1)

ss = gamma(jax.nn.one_hot(species, 1),params["gamma"])
# gamma(species,params)
ss
# Out:
# Array([[5.2441654],
#        [5.2441654],
#        [5.2441654],
#        [5.2441654],
#        [5.2441654]], dtype=float32)

# %%
R = Rs[0][0]

def dist(*args):
    disp = displacement(*args)
    return jnp.sqrt(jnp.square(disp).sum())

dij = vmap(dist, in_axes=(0, 0))(R[senders], R[receivers])

def acceleration_fn(params, graph):
    acc = cal_acceleration(params, graph, mpass=1)
    return acc


def acc_fn(species):
    state_graph = jraph.GraphsTuple(nodes={
        "position": R,
        "type": species
    },
        edges={"dij": dij},
        senders=senders,
        receivers=receivers,
        n_node=jnp.array([R.shape[0]]),
        n_edge=jnp.array([senders.shape[0]]),
        globals={})
    
    def apply(R, params):
        state_graph.nodes.update(position=R)
        state_graph.edges.update(dij=vmap(dist, in_axes=(0, 0))(R[senders], R[receivers]))
        return acceleration_fn(params, state_graph)
    return apply

def gamma_fn(species):    
    def fn(params):
        return gamma(jax.nn.one_hot(species, 1),params)    
    return fn

apply_fn = acc_fn(species)
gamma_fn = gamma_fn(species)

def force_fn_model(x, params): return apply_fn(x, params["F_pos"])
def gamma_fn_model(params): return gamma_fn(params["gamma"])

# gamma_fn_model(params)

# %%
def next_step_pos_gamma(force_fn_model, gamma_fn_model, shift, dt, kT, mass, runs, key):
    key, split = random.split(key)
    def fn(x, params):
        for i in range(runs):
            # calculate the force
            force = force_fn_model(x, params)
            _gamma = gamma_fn_model(params)
            xi = random.normal(split, x.shape, x.dtype)
            nu = f32(1) / lax.mul(mass.reshape(-1,1) , _gamma)
            x = x+ force * dt * nu + jnp.sqrt(f32(2) * kT * dt * nu) * xi
        return x, _gamma
    return fn

# %%
rng_key = random.PRNGKey(0)
rng_key, subkey = random.split(rng_key)

next_step_pos_gamma_fn = next_step_pos_gamma(force_fn_model, gamma_fn_model, shift, dt, kT, masses, runs, subkey)
v_next_step_pos_gamma_fn = vmap(next_step_pos_gamma_fn, in_axes=(0, None))
v_v_next_step_pos_gamma_fn = vmap(v_next_step_pos_gamma_fn, in_axes=(0, None))

# %%
@jit
def loss_fn(params, Rs, Rs_1_ac,A=1, B=500): # A=4, B=996 wf=0.996):
    Rs_1_pred, gamma = v_v_next_step_pos_gamma_fn(Rs, params)
    var =1/gamma
    return GaussianNLL(var, Rs_1_pred, Rs_1_ac, A, B)

def gloss(*args):
    return value_and_grad(loss_fn)(*args)

def update(i, opt_state, params, loss__, *data):
    """ Compute the gradient for a batch and update the parameters """
    value, grads_ = gloss(params, *data)
    opt_state = opt_update(i, grads_, opt_state)
    return opt_state, get_params(opt_state), value

@jit
def step(i, ps, *args):
    return update(i, *ps, *args)

opt_init, opt_update_, get_params = optimizers.adam(lr)

@jit
def opt_update(i, grads_, opt_state):
    grads_ = jax.tree_map(jnp.nan_to_num, grads_)
    grads_ = jax.tree_map(partial(jnp.clip, a_min=-1000.0, a_max=1000.0), grads_)
    return opt_update_(i, grads_, opt_state)

def batching(*args, size=None):
    L = len(args[0])
    if size != None:
        nbatches1 = int((L - 0.5) // size) + 1
        nbatches2 = max(1, nbatches1 - 1)
        size1 = int(L/nbatches1)
        size2 = int(L/nbatches2)
        if size1*nbatches1 > size2*nbatches2:
            size = size1
            nbatches = nbatches1
        else:
            size = size2
            nbatches = nbatches2
    else:
        nbatches = 1
        size = L
    
    newargs = []
    for arg in args:
        newargs += [jnp.array([arg[i*size:(i+1)*size]
                                for i in range(nbatches)])]
    return newargs

bRs_in, bRs_out = batching(Rs_in, Rs_out, size=min(len(Rs_in), batch_size))

print(f"training ...")

opt_state = opt_init(params)
epoch = 0
optimizer_step = -1
larray = []
ltarray = []
last_loss = 1000

for epoch in range(epochs):
    l = 0.0
    count = 0
    for data in zip(bRs_in, bRs_out):
        optimizer_step += 1
        opt_state, params, l_ = step(
            optimizer_step, (opt_state, params, 0), *data)
        l += l_
        count+=1
    # print("epoch,countttttt: ", epoch,count)
    # opt_state, params, l_ = step(optimizer_step, (opt_state, params, 0), Rs, Vs, Fs)
    l = l/count
    larray += [l]
    # ltarray += [loss_fn(params, bRs_in, bVs_in, bRs_out)]
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}/{epochs} Loss (MSE):  train={larray[-1]}")#, test={ltarray[-1]}")
    if epoch % 100 == 0:
        print('gammaaaaa: ', gamma_fn_model(params))
        metadata = {
            "savedat": epoch,
            # "mpass": mpass,
            }
        savefile(f"fgnode_trained_model.dil",
                    params, metadata=metadata)
        # savefile(f"loss_array.dil", (larray, ltarray), metadata=metadata)
        savefile(f"loss_array.dil", larray, metadata=metadata)
        if last_loss > larray[-1]:
            last_loss = larray[-1]
            savefile(f"fgnode_trained_model_low.dil",
                        params, metadata=metadata)
        fig, axs = panel(1, 1)
        # plt.semilogy(larray, label="Training")
        plt.plot(larray, label="Training")
        # plt.semilogy(ltarray, label="Test")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.savefig(_filename(f"training_loss.png"))

fig, axs = panel(1, 1)
# plt.semilogy(larray, label="Training")
plt.plot(larray, label="Training")
# plt.semilogy(ltarray, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.savefig(_filename(f"training_loss.png"))

params = get_params(opt_state)
savefile(f"fgnode_trained_model.dil", params, metadata=metadata)
# savefile(f"loss_array.dil", (larray, ltarray), metadata=metadata)

if last_loss > larray[-1]:
    last_loss = larray[-1]
    savefile(f"fgnode_trained_model_low.dil", params, metadata=metadata)
# Out:
# training ...
# Epoch: 0/10000 Loss (MSE):  train=4.629815578460693
# gammaaaaa:  [[5.229261]
#  [5.229261]
#  [5.229261]
#  [5.229261]
#  [5.229261]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 10/10000 Loss (MSE):  train=4.480149269104004
# Epoch: 20/10000 Loss (MSE):  train=4.334677219390869
# Epoch: 30/10000 Loss (MSE):  train=4.186535358428955
# Epoch: 40/10000 Loss (MSE):  train=4.0309977531433105
# Epoch: 50/10000 Loss (MSE):  train=3.86698579788208
# Epoch: 60/10000 Loss (MSE):  train=3.699244976043701
# Epoch: 70/10000 Loss (MSE):  train=3.5371193885803223
# Epoch: 80/10000 Loss (MSE):  train=3.396890878677368
# Epoch: 90/10000 Loss (MSE):  train=3.286440134048462
# Epoch: 100/10000 Loss (MSE):  train=3.186985731124878
# gammaaaaa:  [[3.8961604]
#  [3.8961604]
#  [3.8961604]
#  [3.8961604]
#  [3.8961606]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 110/10000 Loss (MSE):  train=3.092146635055542
# Epoch: 120/10000 Loss (MSE):  train=3.0011115074157715
# Epoch: 130/10000 Loss (MSE):  train=2.9136316776275635
# Epoch: 140/10000 Loss (MSE):  train=2.8295531272888184
# Epoch: 150/10000 Loss (MSE):  train=2.748732089996338
# Epoch: 160/10000 Loss (MSE):  train=2.6710331439971924
# Epoch: 170/10000 Loss (MSE):  train=2.5955820083618164
# Epoch: 180/10000 Loss (MSE):  train=2.519744873046875
# Epoch: 190/10000 Loss (MSE):  train=2.4501519203186035
# Epoch: 200/10000 Loss (MSE):  train=2.3859896659851074
# gammaaaaa:  [[2.8486266]
#  [2.8486266]
#  [2.8486266]
#  [2.8486266]
#  [2.8486266]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 210/10000 Loss (MSE):  train=2.326145648956299
# Epoch: 220/10000 Loss (MSE):  train=2.2689285278320312
# Epoch: 230/10000 Loss (MSE):  train=2.214111328125
# Epoch: 240/10000 Loss (MSE):  train=2.1617071628570557
# Epoch: 250/10000 Loss (MSE):  train=2.1117355823516846
# Epoch: 260/10000 Loss (MSE):  train=2.064213275909424
# Epoch: 270/10000 Loss (MSE):  train=2.019160032272339
# Epoch: 280/10000 Loss (MSE):  train=1.976600170135498
# Epoch: 290/10000 Loss (MSE):  train=1.9365544319152832
# Epoch: 300/10000 Loss (MSE):  train=1.8990371227264404
# gammaaaaa:  [[2.0219069]
#  [2.0219069]
#  [2.0219069]
#  [2.0219069]
#  [2.0219069]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 310/10000 Loss (MSE):  train=1.864058494567871
# Epoch: 320/10000 Loss (MSE):  train=1.8316105604171753
# Epoch: 330/10000 Loss (MSE):  train=1.80167818069458
# Epoch: 340/10000 Loss (MSE):  train=1.774223804473877
# Epoch: 350/10000 Loss (MSE):  train=1.7491998672485352
# Epoch: 360/10000 Loss (MSE):  train=1.7265329360961914
# Epoch: 370/10000 Loss (MSE):  train=1.7061357498168945
# Epoch: 380/10000 Loss (MSE):  train=1.6879034042358398
# Epoch: 390/10000 Loss (MSE):  train=1.671715259552002
# Epoch: 400/10000 Loss (MSE):  train=1.6574373245239258
# gammaaaaa:  [[1.4507978]
#  [1.4507978]
#  [1.4507978]
#  [1.4507978]
#  [1.4507978]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 410/10000 Loss (MSE):  train=1.6449333429336548
# Epoch: 420/10000 Loss (MSE):  train=1.6340538263320923
# Epoch: 430/10000 Loss (MSE):  train=1.6246492862701416
# Epoch: 440/10000 Loss (MSE):  train=1.6165752410888672
# Epoch: 450/10000 Loss (MSE):  train=1.6096858978271484
# Epoch: 460/10000 Loss (MSE):  train=1.6038466691970825
# Epoch: 470/10000 Loss (MSE):  train=1.5989223718643188
# Epoch: 480/10000 Loss (MSE):  train=1.5947973728179932
# Epoch: 490/10000 Loss (MSE):  train=1.591360092163086
# Epoch: 500/10000 Loss (MSE):  train=1.5885118246078491
# gammaaaaa:  [[1.1567361]
#  [1.1567361]
#  [1.1567361]
#  [1.1567361]
#  [1.1567363]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 510/10000 Loss (MSE):  train=1.5861642360687256
# Epoch: 520/10000 Loss (MSE):  train=1.5842372179031372
# Epoch: 530/10000 Loss (MSE):  train=1.582663655281067
# Epoch: 540/10000 Loss (MSE):  train=1.5813881158828735
# Epoch: 550/10000 Loss (MSE):  train=1.580356240272522
# Epoch: 560/10000 Loss (MSE):  train=1.5795211791992188
# Epoch: 570/10000 Loss (MSE):  train=1.5788447856903076
# Epoch: 580/10000 Loss (MSE):  train=1.5782948732376099
# Epoch: 590/10000 Loss (MSE):  train=1.577854871749878
# Epoch: 600/10000 Loss (MSE):  train=1.577506422996521
# gammaaaaa:  [[1.0422807]
#  [1.0422807]
#  [1.0422807]
#  [1.0422807]
#  [1.0422807]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 610/10000 Loss (MSE):  train=1.5772287845611572
# Epoch: 620/10000 Loss (MSE):  train=1.577007532119751
# Epoch: 630/10000 Loss (MSE):  train=1.5768300294876099
# Epoch: 640/10000 Loss (MSE):  train=1.5766870975494385
# Epoch: 650/10000 Loss (MSE):  train=1.5765701532363892
# Epoch: 660/10000 Loss (MSE):  train=1.576474666595459
# Epoch: 670/10000 Loss (MSE):  train=1.5763940811157227
# Epoch: 680/10000 Loss (MSE):  train=1.5763276815414429
# Epoch: 690/10000 Loss (MSE):  train=1.5762709379196167
# Epoch: 700/10000 Loss (MSE):  train=1.5762193202972412
# gammaaaaa:  [[1.007684 ]
#  [1.007684 ]
#  [1.007684 ]
#  [1.007684 ]
#  [1.0076839]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 710/10000 Loss (MSE):  train=1.5761748552322388
# Epoch: 720/10000 Loss (MSE):  train=1.576133370399475
# Epoch: 730/10000 Loss (MSE):  train=1.576094388961792
# Epoch: 740/10000 Loss (MSE):  train=1.5760587453842163
# Epoch: 750/10000 Loss (MSE):  train=1.5760244131088257
# Epoch: 760/10000 Loss (MSE):  train=1.5759916305541992
# Epoch: 770/10000 Loss (MSE):  train=1.575961709022522
# Epoch: 780/10000 Loss (MSE):  train=1.5759291648864746
# Epoch: 790/10000 Loss (MSE):  train=1.5759004354476929
# Epoch: 800/10000 Loss (MSE):  train=1.5758693218231201
# gammaaaaa:  [[1.0000317]
#  [1.0000317]
#  [1.0000317]
#  [1.0000317]
#  [1.0000317]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 810/10000 Loss (MSE):  train=1.575840950012207
# Epoch: 820/10000 Loss (MSE):  train=1.575812816619873
# Epoch: 830/10000 Loss (MSE):  train=1.5757853984832764
# Epoch: 840/10000 Loss (MSE):  train=1.575758457183838
# Epoch: 850/10000 Loss (MSE):  train=1.575730800628662
# Epoch: 860/10000 Loss (MSE):  train=1.575703740119934
# Epoch: 870/10000 Loss (MSE):  train=1.5756771564483643
# Epoch: 880/10000 Loss (MSE):  train=1.5756500959396362
# Epoch: 890/10000 Loss (MSE):  train=1.5756242275238037
# Epoch: 900/10000 Loss (MSE):  train=1.5755975246429443
# gammaaaaa:  [[0.9988983]
#  [0.9988983]
#  [0.9988983]
#  [0.9988983]
#  [0.9988983]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 910/10000 Loss (MSE):  train=1.5755724906921387
# Epoch: 920/10000 Loss (MSE):  train=1.5755468606948853
# Epoch: 930/10000 Loss (MSE):  train=1.5755211114883423
# Epoch: 940/10000 Loss (MSE):  train=1.5754964351654053
# Epoch: 950/10000 Loss (MSE):  train=1.5754703283309937
# Epoch: 960/10000 Loss (MSE):  train=1.5754444599151611
# Epoch: 970/10000 Loss (MSE):  train=1.5754197835922241
# Epoch: 980/10000 Loss (MSE):  train=1.5753954648971558
# Epoch: 990/10000 Loss (MSE):  train=1.5753682851791382
# Epoch: 1000/10000 Loss (MSE):  train=1.575344204902649
# gammaaaaa:  [[0.9987801]
#  [0.9987801]
#  [0.9987801]
#  [0.9987801]
#  [0.9987801]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1010/10000 Loss (MSE):  train=1.5753189325332642
# Epoch: 1020/10000 Loss (MSE):  train=1.5752930641174316
# Epoch: 1030/10000 Loss (MSE):  train=1.5752670764923096
# Epoch: 1040/10000 Loss (MSE):  train=1.5752415657043457
# Epoch: 1050/10000 Loss (MSE):  train=1.5752172470092773
# Epoch: 1060/10000 Loss (MSE):  train=1.5751910209655762
# Epoch: 1070/10000 Loss (MSE):  train=1.575165033340454
# Epoch: 1080/10000 Loss (MSE):  train=1.5751382112503052
# Epoch: 1090/10000 Loss (MSE):  train=1.575111985206604
# Epoch: 1100/10000 Loss (MSE):  train=1.5750854015350342
# gammaaaaa:  [[0.99874383]
#  [0.99874383]
#  [0.99874383]
#  [0.99874383]
#  [0.99874383]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1110/10000 Loss (MSE):  train=1.5750576257705688
# Epoch: 1120/10000 Loss (MSE):  train=1.5750306844711304
# Epoch: 1130/10000 Loss (MSE):  train=1.5750007629394531
# Epoch: 1140/10000 Loss (MSE):  train=1.5749682188034058
# Epoch: 1150/10000 Loss (MSE):  train=1.5749315023422241
# Epoch: 1160/10000 Loss (MSE):  train=1.5748875141143799
# Epoch: 1170/10000 Loss (MSE):  train=1.5748460292816162
# Epoch: 1180/10000 Loss (MSE):  train=1.5748106241226196
# Epoch: 1190/10000 Loss (MSE):  train=1.5747768878936768
# Epoch: 1200/10000 Loss (MSE):  train=1.5747448205947876
# gammaaaaa:  [[0.9987014]
#  [0.9987014]
#  [0.9987014]
#  [0.9987014]
#  [0.9987014]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1210/10000 Loss (MSE):  train=1.5747125148773193
# Epoch: 1220/10000 Loss (MSE):  train=1.5746783018112183
# Epoch: 1230/10000 Loss (MSE):  train=1.5746445655822754
# Epoch: 1240/10000 Loss (MSE):  train=1.574609637260437
# Epoch: 1250/10000 Loss (MSE):  train=1.5745748281478882
# Epoch: 1260/10000 Loss (MSE):  train=1.5745397806167603
# Epoch: 1270/10000 Loss (MSE):  train=1.574504017829895
# Epoch: 1280/10000 Loss (MSE):  train=1.5744690895080566
# Epoch: 1290/10000 Loss (MSE):  train=1.5744305849075317
# Epoch: 1300/10000 Loss (MSE):  train=1.5743918418884277
# gammaaaaa:  [[0.9986225]
#  [0.9986225]
#  [0.9986225]
#  [0.9986225]
#  [0.9986225]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1310/10000 Loss (MSE):  train=1.5743508338928223
# Epoch: 1320/10000 Loss (MSE):  train=1.5743083953857422
# Epoch: 1330/10000 Loss (MSE):  train=1.5742608308792114
# Epoch: 1340/10000 Loss (MSE):  train=1.574210524559021
# Epoch: 1350/10000 Loss (MSE):  train=1.5741569995880127
# Epoch: 1360/10000 Loss (MSE):  train=1.5741021633148193
# Epoch: 1370/10000 Loss (MSE):  train=1.5740492343902588
# Epoch: 1380/10000 Loss (MSE):  train=1.5739967823028564
# Epoch: 1390/10000 Loss (MSE):  train=1.5739439725875854
# Epoch: 1400/10000 Loss (MSE):  train=1.5738883018493652
# gammaaaaa:  [[0.9985316]
#  [0.9985316]
#  [0.9985316]
#  [0.9985316]
#  [0.9985316]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1410/10000 Loss (MSE):  train=1.5738322734832764
# Epoch: 1420/10000 Loss (MSE):  train=1.573774814605713
# Epoch: 1430/10000 Loss (MSE):  train=1.573714256286621
# Epoch: 1440/10000 Loss (MSE):  train=1.5736500024795532
# Epoch: 1450/10000 Loss (MSE):  train=1.5735831260681152
# Epoch: 1460/10000 Loss (MSE):  train=1.5735113620758057
# Epoch: 1470/10000 Loss (MSE):  train=1.5734357833862305
# Epoch: 1480/10000 Loss (MSE):  train=1.5733548402786255
# Epoch: 1490/10000 Loss (MSE):  train=1.5732649564743042
# Epoch: 1500/10000 Loss (MSE):  train=1.5731496810913086
# gammaaaaa:  [[0.9983278]
#  [0.9983278]
#  [0.9983278]
#  [0.9983278]
#  [0.9983278]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1510/10000 Loss (MSE):  train=1.5729587078094482
# Epoch: 1520/10000 Loss (MSE):  train=1.5727218389511108
# Epoch: 1530/10000 Loss (MSE):  train=1.572518229484558
# Epoch: 1540/10000 Loss (MSE):  train=1.5723299980163574
# Epoch: 1550/10000 Loss (MSE):  train=1.5721468925476074
# Epoch: 1560/10000 Loss (MSE):  train=1.5719672441482544
# Epoch: 1570/10000 Loss (MSE):  train=1.5717854499816895
# Epoch: 1580/10000 Loss (MSE):  train=1.5716044902801514
# Epoch: 1590/10000 Loss (MSE):  train=1.571423053741455
# Epoch: 1600/10000 Loss (MSE):  train=1.5712411403656006
# gammaaaaa:  [[0.99813586]
#  [0.99813586]
#  [0.99813586]
#  [0.99813586]
#  [0.99813586]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1610/10000 Loss (MSE):  train=1.5710580348968506
# Epoch: 1620/10000 Loss (MSE):  train=1.570873737335205
# Epoch: 1630/10000 Loss (MSE):  train=1.5706895589828491
# Epoch: 1640/10000 Loss (MSE):  train=1.5705020427703857
# Epoch: 1650/10000 Loss (MSE):  train=1.5703140497207642
# Epoch: 1660/10000 Loss (MSE):  train=1.5701255798339844
# Epoch: 1670/10000 Loss (MSE):  train=1.5699366331100464
# Epoch: 1680/10000 Loss (MSE):  train=1.5697476863861084
# Epoch: 1690/10000 Loss (MSE):  train=1.5695595741271973
# Epoch: 1700/10000 Loss (MSE):  train=1.569374442100525
# gammaaaaa:  [[0.9980067]
#  [0.9980067]
#  [0.9980067]
#  [0.9980067]
#  [0.9980067]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1710/10000 Loss (MSE):  train=1.5691919326782227
# Epoch: 1720/10000 Loss (MSE):  train=1.5690104961395264
# Epoch: 1730/10000 Loss (MSE):  train=1.5688326358795166
# Epoch: 1740/10000 Loss (MSE):  train=1.5686538219451904
# Epoch: 1750/10000 Loss (MSE):  train=1.5684701204299927
# Epoch: 1760/10000 Loss (MSE):  train=1.5682755708694458
# Epoch: 1770/10000 Loss (MSE):  train=1.568049430847168
# Epoch: 1780/10000 Loss (MSE):  train=1.567791223526001
# Epoch: 1790/10000 Loss (MSE):  train=1.567521095275879
# Epoch: 1800/10000 Loss (MSE):  train=1.5672428607940674
# gammaaaaa:  [[0.99764454]
#  [0.99764454]
#  [0.99764454]
#  [0.99764454]
#  [0.99764454]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1810/10000 Loss (MSE):  train=1.5669666528701782
# Epoch: 1820/10000 Loss (MSE):  train=1.566706895828247
# Epoch: 1830/10000 Loss (MSE):  train=1.5664657354354858
# Epoch: 1840/10000 Loss (MSE):  train=1.5662429332733154
# Epoch: 1850/10000 Loss (MSE):  train=1.5660334825515747
# Epoch: 1860/10000 Loss (MSE):  train=1.5658317804336548
# Epoch: 1870/10000 Loss (MSE):  train=1.5656379461288452
# Epoch: 1880/10000 Loss (MSE):  train=1.5654513835906982
# Epoch: 1890/10000 Loss (MSE):  train=1.5652674436569214
# Epoch: 1900/10000 Loss (MSE):  train=1.5650825500488281
# gammaaaaa:  [[0.99755937]
#  [0.99755937]
#  [0.99755937]
#  [0.99755937]
#  [0.9975594 ]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 1910/10000 Loss (MSE):  train=1.564888596534729
# Epoch: 1920/10000 Loss (MSE):  train=1.564674735069275
# Epoch: 1930/10000 Loss (MSE):  train=1.5644478797912598
# Epoch: 1940/10000 Loss (MSE):  train=1.5642236471176147
# Epoch: 1950/10000 Loss (MSE):  train=1.564015507698059
# Epoch: 1960/10000 Loss (MSE):  train=1.563819169998169
# Epoch: 1970/10000 Loss (MSE):  train=1.563625454902649
# Epoch: 1980/10000 Loss (MSE):  train=1.5634232759475708
# Epoch: 1990/10000 Loss (MSE):  train=1.5632106065750122
# Epoch: 2000/10000 Loss (MSE):  train=1.5630199909210205
# gammaaaaa:  [[0.9975368]
#  [0.9975368]
#  [0.9975368]
#  [0.9975368]
#  [0.9975367]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# /Users/sureshjyoti/GitHub/BGNODE_scratch/.venv_jaxbrow/lib/python3.9/site-packages/shadow/plot.py:181: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize, **kwargs)
# Epoch: 2010/10000 Loss (MSE):  train=1.5628387928009033
# Epoch: 2020/10000 Loss (MSE):  train=1.5626450777053833
# Epoch: 2030/10000 Loss (MSE):  train=1.562455177307129
# Epoch: 2040/10000 Loss (MSE):  train=1.5622739791870117
# Epoch: 2050/10000 Loss (MSE):  train=1.5620949268341064
# Epoch: 2060/10000 Loss (MSE):  train=1.5619170665740967
# Epoch: 2070/10000 Loss (MSE):  train=1.5617421865463257
# Epoch: 2080/10000 Loss (MSE):  train=1.5615699291229248
# Epoch: 2090/10000 Loss (MSE):  train=1.561400055885315
# Epoch: 2100/10000 Loss (MSE):  train=1.5612326860427856
# gammaaaaa:  [[0.9976532]
#  [0.9976532]
#  [0.9976532]
#  [0.9976532]
#  [0.9976532]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2110/10000 Loss (MSE):  train=1.56106698513031
# Epoch: 2120/10000 Loss (MSE):  train=1.5609040260314941
# Epoch: 2130/10000 Loss (MSE):  train=1.5607407093048096
# Epoch: 2140/10000 Loss (MSE):  train=1.5605754852294922
# Epoch: 2150/10000 Loss (MSE):  train=1.5604130029678345
# Epoch: 2160/10000 Loss (MSE):  train=1.560254693031311
# Epoch: 2170/10000 Loss (MSE):  train=1.5600996017456055
# Epoch: 2180/10000 Loss (MSE):  train=1.559945821762085
# Epoch: 2190/10000 Loss (MSE):  train=1.559793472290039
# Epoch: 2200/10000 Loss (MSE):  train=1.5596404075622559
# gammaaaaa:  [[0.997838 ]
#  [0.997838 ]
#  [0.997838 ]
#  [0.997838 ]
#  [0.9978382]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2210/10000 Loss (MSE):  train=1.5594888925552368
# Epoch: 2220/10000 Loss (MSE):  train=1.559335708618164
# Epoch: 2230/10000 Loss (MSE):  train=1.559184193611145
# Epoch: 2240/10000 Loss (MSE):  train=1.5590295791625977
# Epoch: 2250/10000 Loss (MSE):  train=1.558875322341919
# Epoch: 2260/10000 Loss (MSE):  train=1.5587202310562134
# Epoch: 2270/10000 Loss (MSE):  train=1.5585651397705078
# Epoch: 2280/10000 Loss (MSE):  train=1.5584083795547485
# Epoch: 2290/10000 Loss (MSE):  train=1.5582494735717773
# Epoch: 2300/10000 Loss (MSE):  train=1.558090329170227
# gammaaaaa:  [[0.9978496 ]
#  [0.9978496 ]
#  [0.9978496 ]
#  [0.9978496 ]
#  [0.99784964]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2310/10000 Loss (MSE):  train=1.5579304695129395
# Epoch: 2320/10000 Loss (MSE):  train=1.5577681064605713
# Epoch: 2330/10000 Loss (MSE):  train=1.5576069355010986
# Epoch: 2340/10000 Loss (MSE):  train=1.557444453239441
# Epoch: 2350/10000 Loss (MSE):  train=1.5572807788848877
# Epoch: 2360/10000 Loss (MSE):  train=1.5571160316467285
# Epoch: 2370/10000 Loss (MSE):  train=1.5569524765014648
# Epoch: 2380/10000 Loss (MSE):  train=1.5567882061004639
# Epoch: 2390/10000 Loss (MSE):  train=1.5566225051879883
# Epoch: 2400/10000 Loss (MSE):  train=1.5564576387405396
# gammaaaaa:  [[0.99778473]
#  [0.99778473]
#  [0.99778473]
#  [0.99778473]
#  [0.9977848 ]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2410/10000 Loss (MSE):  train=1.5562926530838013
# Epoch: 2420/10000 Loss (MSE):  train=1.5561285018920898
# Epoch: 2430/10000 Loss (MSE):  train=1.5559618473052979
# Epoch: 2440/10000 Loss (MSE):  train=1.5557961463928223
# Epoch: 2450/10000 Loss (MSE):  train=1.5556304454803467
# Epoch: 2460/10000 Loss (MSE):  train=1.5554648637771606
# Epoch: 2470/10000 Loss (MSE):  train=1.5552994012832642
# Epoch: 2480/10000 Loss (MSE):  train=1.5551332235336304
# Epoch: 2490/10000 Loss (MSE):  train=1.5549691915512085
# Epoch: 2500/10000 Loss (MSE):  train=1.554802656173706
# gammaaaaa:  [[0.9976708]
#  [0.9976708]
#  [0.9976708]
#  [0.9976708]
#  [0.9976708]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2510/10000 Loss (MSE):  train=1.554635763168335
# Epoch: 2520/10000 Loss (MSE):  train=1.5544700622558594
# Epoch: 2530/10000 Loss (MSE):  train=1.5543038845062256
# Epoch: 2540/10000 Loss (MSE):  train=1.5541356801986694
# Epoch: 2550/10000 Loss (MSE):  train=1.5539673566818237
# Epoch: 2560/10000 Loss (MSE):  train=1.5537972450256348
# Epoch: 2570/10000 Loss (MSE):  train=1.5536290407180786
# Epoch: 2580/10000 Loss (MSE):  train=1.5534570217132568
# Epoch: 2590/10000 Loss (MSE):  train=1.5532842874526978
# Epoch: 2600/10000 Loss (MSE):  train=1.5531039237976074
# gammaaaaa:  [[0.997455  ]
#  [0.997455  ]
#  [0.997455  ]
#  [0.997455  ]
#  [0.99745506]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2610/10000 Loss (MSE):  train=1.5529170036315918
# Epoch: 2620/10000 Loss (MSE):  train=1.552727222442627
# Epoch: 2630/10000 Loss (MSE):  train=1.552536964416504
# Epoch: 2640/10000 Loss (MSE):  train=1.5523535013198853
# Epoch: 2650/10000 Loss (MSE):  train=1.5521701574325562
# Epoch: 2660/10000 Loss (MSE):  train=1.5519859790802002
# Epoch: 2670/10000 Loss (MSE):  train=1.551804780960083
# Epoch: 2680/10000 Loss (MSE):  train=1.551621675491333
# Epoch: 2690/10000 Loss (MSE):  train=1.5514394044876099
# Epoch: 2700/10000 Loss (MSE):  train=1.5512566566467285
# gammaaaaa:  [[0.9972167]
#  [0.9972167]
#  [0.9972167]
#  [0.9972167]
#  [0.9972166]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2710/10000 Loss (MSE):  train=1.5510731935501099
# Epoch: 2720/10000 Loss (MSE):  train=1.550888180732727
# Epoch: 2730/10000 Loss (MSE):  train=1.550703525543213
# Epoch: 2740/10000 Loss (MSE):  train=1.5505187511444092
# Epoch: 2750/10000 Loss (MSE):  train=1.5503337383270264
# Epoch: 2760/10000 Loss (MSE):  train=1.5501478910446167
# Epoch: 2770/10000 Loss (MSE):  train=1.5499616861343384
# Epoch: 2780/10000 Loss (MSE):  train=1.5497761964797974
# Epoch: 2790/10000 Loss (MSE):  train=1.5495917797088623
# Epoch: 2800/10000 Loss (MSE):  train=1.5494067668914795
# gammaaaaa:  [[0.99697703]
#  [0.99697703]
#  [0.99697703]
#  [0.99697703]
#  [0.99697703]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2810/10000 Loss (MSE):  train=1.549222469329834
# Epoch: 2820/10000 Loss (MSE):  train=1.5490403175354004
# Epoch: 2830/10000 Loss (MSE):  train=1.5488604307174683
# Epoch: 2840/10000 Loss (MSE):  train=1.5486818552017212
# Epoch: 2850/10000 Loss (MSE):  train=1.5485036373138428
# Epoch: 2860/10000 Loss (MSE):  train=1.5483280420303345
# Epoch: 2870/10000 Loss (MSE):  train=1.548153281211853
# Epoch: 2880/10000 Loss (MSE):  train=1.547980546951294
# Epoch: 2890/10000 Loss (MSE):  train=1.5478090047836304
# Epoch: 2900/10000 Loss (MSE):  train=1.5476402044296265
# gammaaaaa:  [[0.99686384]
#  [0.99686384]
#  [0.99686384]
#  [0.99686384]
#  [0.99686384]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 2910/10000 Loss (MSE):  train=1.5474718809127808
# Epoch: 2920/10000 Loss (MSE):  train=1.5473042726516724
# Epoch: 2930/10000 Loss (MSE):  train=1.5471394062042236
# Epoch: 2940/10000 Loss (MSE):  train=1.5469753742218018
# Epoch: 2950/10000 Loss (MSE):  train=1.5468125343322754
# Epoch: 2960/10000 Loss (MSE):  train=1.5466511249542236
# Epoch: 2970/10000 Loss (MSE):  train=1.5464913845062256
# Epoch: 2980/10000 Loss (MSE):  train=1.5463318824768066
# Epoch: 2990/10000 Loss (MSE):  train=1.5461757183074951
# Epoch: 3000/10000 Loss (MSE):  train=1.546019434928894
# gammaaaaa:  [[0.9968631]
#  [0.9968631]
#  [0.9968631]
#  [0.9968631]
#  [0.9968631]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3010/10000 Loss (MSE):  train=1.5458638668060303
# Epoch: 3020/10000 Loss (MSE):  train=1.5457074642181396
# Epoch: 3030/10000 Loss (MSE):  train=1.5455530881881714
# Epoch: 3040/10000 Loss (MSE):  train=1.5453988313674927
# Epoch: 3050/10000 Loss (MSE):  train=1.5452446937561035
# Epoch: 3060/10000 Loss (MSE):  train=1.545088291168213
# Epoch: 3070/10000 Loss (MSE):  train=1.5449306964874268
# Epoch: 3080/10000 Loss (MSE):  train=1.5447719097137451
# Epoch: 3090/10000 Loss (MSE):  train=1.5446031093597412
# Epoch: 3100/10000 Loss (MSE):  train=1.5444302558898926
# gammaaaaa:  [[0.99683625]
#  [0.99683625]
#  [0.99683625]
#  [0.99683625]
#  [0.9968362 ]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3110/10000 Loss (MSE):  train=1.5442619323730469
# Epoch: 3120/10000 Loss (MSE):  train=1.5440860986709595
# Epoch: 3130/10000 Loss (MSE):  train=1.5438519716262817
# Epoch: 3140/10000 Loss (MSE):  train=1.5435245037078857
# Epoch: 3150/10000 Loss (MSE):  train=1.5433090925216675
# Epoch: 3160/10000 Loss (MSE):  train=1.5431267023086548
# Epoch: 3170/10000 Loss (MSE):  train=1.5429584980010986
# Epoch: 3180/10000 Loss (MSE):  train=1.5428000688552856
# Epoch: 3190/10000 Loss (MSE):  train=1.5426476001739502
# Epoch: 3200/10000 Loss (MSE):  train=1.5425019264221191
# gammaaaaa:  [[0.9972539]
#  [0.9972539]
#  [0.9972539]
#  [0.9972539]
#  [0.9972539]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3210/10000 Loss (MSE):  train=1.5423600673675537
# Epoch: 3220/10000 Loss (MSE):  train=1.5422208309173584
# Epoch: 3230/10000 Loss (MSE):  train=1.5420866012573242
# Epoch: 3240/10000 Loss (MSE):  train=1.5419540405273438
# Epoch: 3250/10000 Loss (MSE):  train=1.5418245792388916
# Epoch: 3260/10000 Loss (MSE):  train=1.5416959524154663
# Epoch: 3270/10000 Loss (MSE):  train=1.541569709777832
# Epoch: 3280/10000 Loss (MSE):  train=1.5414458513259888
# Epoch: 3290/10000 Loss (MSE):  train=1.5413222312927246
# Epoch: 3300/10000 Loss (MSE):  train=1.5412018299102783
# gammaaaaa:  [[0.9975173]
#  [0.9975173]
#  [0.9975173]
#  [0.9975173]
#  [0.9975173]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3310/10000 Loss (MSE):  train=1.5410816669464111
# Epoch: 3320/10000 Loss (MSE):  train=1.5409626960754395
# Epoch: 3330/10000 Loss (MSE):  train=1.5408458709716797
# Epoch: 3340/10000 Loss (MSE):  train=1.5407288074493408
# Epoch: 3350/10000 Loss (MSE):  train=1.5406134128570557
# Epoch: 3360/10000 Loss (MSE):  train=1.5404986143112183
# Epoch: 3370/10000 Loss (MSE):  train=1.5403858423233032
# Epoch: 3380/10000 Loss (MSE):  train=1.5402722358703613
# Epoch: 3390/10000 Loss (MSE):  train=1.5401599407196045
# Epoch: 3400/10000 Loss (MSE):  train=1.5400491952896118
# gammaaaaa:  [[0.9976913]
#  [0.9976913]
#  [0.9976913]
#  [0.9976913]
#  [0.9976913]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3410/10000 Loss (MSE):  train=1.5399386882781982
# Epoch: 3420/10000 Loss (MSE):  train=1.539828896522522
# Epoch: 3430/10000 Loss (MSE):  train=1.5397193431854248
# Epoch: 3440/10000 Loss (MSE):  train=1.5396095514297485
# Epoch: 3450/10000 Loss (MSE):  train=1.539501667022705
# Epoch: 3460/10000 Loss (MSE):  train=1.5393917560577393
# Epoch: 3470/10000 Loss (MSE):  train=1.5392838716506958
# Epoch: 3480/10000 Loss (MSE):  train=1.5391767024993896
# Epoch: 3490/10000 Loss (MSE):  train=1.5390682220458984
# Epoch: 3500/10000 Loss (MSE):  train=1.5389584302902222
# gammaaaaa:  [[0.997814]
#  [0.997814]
#  [0.997814]
#  [0.997814]
#  [0.997814]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3510/10000 Loss (MSE):  train=1.5388482809066772
# Epoch: 3520/10000 Loss (MSE):  train=1.5387346744537354
# Epoch: 3530/10000 Loss (MSE):  train=1.5386173725128174
# Epoch: 3540/10000 Loss (MSE):  train=1.5384979248046875
# Epoch: 3550/10000 Loss (MSE):  train=1.5383778810501099
# Epoch: 3560/10000 Loss (MSE):  train=1.5382602214813232
# Epoch: 3570/10000 Loss (MSE):  train=1.5381394624710083
# Epoch: 3580/10000 Loss (MSE):  train=1.5380158424377441
# Epoch: 3590/10000 Loss (MSE):  train=1.5378844738006592
# Epoch: 3600/10000 Loss (MSE):  train=1.5377421379089355
# gammaaaaa:  [[0.9977432]
#  [0.9977432]
#  [0.9977432]
#  [0.9977432]
#  [0.9977432]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3610/10000 Loss (MSE):  train=1.5375926494598389
# Epoch: 3620/10000 Loss (MSE):  train=1.537438154220581
# Epoch: 3630/10000 Loss (MSE):  train=1.5372858047485352
# Epoch: 3640/10000 Loss (MSE):  train=1.5371390581130981
# Epoch: 3650/10000 Loss (MSE):  train=1.5369958877563477
# Epoch: 3660/10000 Loss (MSE):  train=1.53685462474823
# Epoch: 3670/10000 Loss (MSE):  train=1.5367122888565063
# Epoch: 3680/10000 Loss (MSE):  train=1.5365697145462036
# Epoch: 3690/10000 Loss (MSE):  train=1.5364248752593994
# Epoch: 3700/10000 Loss (MSE):  train=1.5362800359725952
# gammaaaaa:  [[0.99766034]
#  [0.99766034]
#  [0.99766034]
#  [0.99766034]
#  [0.99766034]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3710/10000 Loss (MSE):  train=1.5361356735229492
# Epoch: 3720/10000 Loss (MSE):  train=1.5359910726547241
# Epoch: 3730/10000 Loss (MSE):  train=1.5358482599258423
# Epoch: 3740/10000 Loss (MSE):  train=1.535709023475647
# Epoch: 3750/10000 Loss (MSE):  train=1.5355730056762695
# Epoch: 3760/10000 Loss (MSE):  train=1.535438060760498
# Epoch: 3770/10000 Loss (MSE):  train=1.5353032350540161
# Epoch: 3780/10000 Loss (MSE):  train=1.5351715087890625
# Epoch: 3790/10000 Loss (MSE):  train=1.5350415706634521
# Epoch: 3800/10000 Loss (MSE):  train=1.5349128246307373
# gammaaaaa:  [[0.99774003]
#  [0.99774003]
#  [0.99774003]
#  [0.99774003]
#  [0.9977401 ]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3810/10000 Loss (MSE):  train=1.5347843170166016
# Epoch: 3820/10000 Loss (MSE):  train=1.5346574783325195
# Epoch: 3830/10000 Loss (MSE):  train=1.5345301628112793
# Epoch: 3840/10000 Loss (MSE):  train=1.5344046354293823
# Epoch: 3850/10000 Loss (MSE):  train=1.534278154373169
# Epoch: 3860/10000 Loss (MSE):  train=1.5341547727584839
# Epoch: 3870/10000 Loss (MSE):  train=1.5340300798416138
# Epoch: 3880/10000 Loss (MSE):  train=1.5339089632034302
# Epoch: 3890/10000 Loss (MSE):  train=1.5337872505187988
# Epoch: 3900/10000 Loss (MSE):  train=1.533665657043457
# gammaaaaa:  [[0.997873]
#  [0.997873]
#  [0.997873]
#  [0.997873]
#  [0.997873]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 3910/10000 Loss (MSE):  train=1.5335465669631958
# Epoch: 3920/10000 Loss (MSE):  train=1.5334280729293823
# Epoch: 3930/10000 Loss (MSE):  train=1.533308982849121
# Epoch: 3940/10000 Loss (MSE):  train=1.5331913232803345
# Epoch: 3950/10000 Loss (MSE):  train=1.5330735445022583
# Epoch: 3960/10000 Loss (MSE):  train=1.5329532623291016
# Epoch: 3970/10000 Loss (MSE):  train=1.5328340530395508
# Epoch: 3980/10000 Loss (MSE):  train=1.5327128171920776
# Epoch: 3990/10000 Loss (MSE):  train=1.5325946807861328
# Epoch: 4000/10000 Loss (MSE):  train=1.532475233078003
# gammaaaaa:  [[0.9979875]
#  [0.9979875]
#  [0.9979875]
#  [0.9979875]
#  [0.9979875]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4010/10000 Loss (MSE):  train=1.5323584079742432
# Epoch: 4020/10000 Loss (MSE):  train=1.532239317893982
# Epoch: 4030/10000 Loss (MSE):  train=1.5321236848831177
# Epoch: 4040/10000 Loss (MSE):  train=1.5320076942443848
# Epoch: 4050/10000 Loss (MSE):  train=1.531893253326416
# Epoch: 4060/10000 Loss (MSE):  train=1.531778335571289
# Epoch: 4070/10000 Loss (MSE):  train=1.531664490699768
# Epoch: 4080/10000 Loss (MSE):  train=1.5315502882003784
# Epoch: 4090/10000 Loss (MSE):  train=1.5314360857009888
# Epoch: 4100/10000 Loss (MSE):  train=1.531322956085205
# gammaaaaa:  [[0.9980123]
#  [0.9980123]
#  [0.9980123]
#  [0.9980123]
#  [0.9980123]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4110/10000 Loss (MSE):  train=1.5312106609344482
# Epoch: 4120/10000 Loss (MSE):  train=1.5310970544815063
# Epoch: 4130/10000 Loss (MSE):  train=1.5309841632843018
# Epoch: 4140/10000 Loss (MSE):  train=1.5308705568313599
# Epoch: 4150/10000 Loss (MSE):  train=1.5307576656341553
# Epoch: 4160/10000 Loss (MSE):  train=1.5306448936462402
# Epoch: 4170/10000 Loss (MSE):  train=1.5305321216583252
# Epoch: 4180/10000 Loss (MSE):  train=1.5304186344146729
# Epoch: 4190/10000 Loss (MSE):  train=1.5303047895431519
# Epoch: 4200/10000 Loss (MSE):  train=1.5301923751831055
# gammaaaaa:  [[0.9980566 ]
#  [0.9980566 ]
#  [0.9980566 ]
#  [0.9980566 ]
#  [0.99805665]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4210/10000 Loss (MSE):  train=1.5300770998001099
# Epoch: 4220/10000 Loss (MSE):  train=1.5299625396728516
# Epoch: 4230/10000 Loss (MSE):  train=1.5298466682434082
# Epoch: 4240/10000 Loss (MSE):  train=1.5297274589538574
# Epoch: 4250/10000 Loss (MSE):  train=1.5296046733856201
# Epoch: 4260/10000 Loss (MSE):  train=1.5294837951660156
# Epoch: 4270/10000 Loss (MSE):  train=1.5293633937835693
# Epoch: 4280/10000 Loss (MSE):  train=1.5292447805404663
# Epoch: 4290/10000 Loss (MSE):  train=1.5291239023208618
# Epoch: 4300/10000 Loss (MSE):  train=1.5290040969848633
# gammaaaaa:  [[0.9981306]
#  [0.9981306]
#  [0.9981306]
#  [0.9981306]
#  [0.9981306]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4310/10000 Loss (MSE):  train=1.5288830995559692
# Epoch: 4320/10000 Loss (MSE):  train=1.528761625289917
# Epoch: 4330/10000 Loss (MSE):  train=1.528641700744629
# Epoch: 4340/10000 Loss (MSE):  train=1.5285205841064453
# Epoch: 4350/10000 Loss (MSE):  train=1.5284007787704468
# Epoch: 4360/10000 Loss (MSE):  train=1.5282807350158691
# Epoch: 4370/10000 Loss (MSE):  train=1.5281637907028198
# Epoch: 4380/10000 Loss (MSE):  train=1.528045892715454
# Epoch: 4390/10000 Loss (MSE):  train=1.527928352355957
# Epoch: 4400/10000 Loss (MSE):  train=1.52781343460083
# gammaaaaa:  [[0.99815595]
#  [0.99815595]
#  [0.99815595]
#  [0.99815595]
#  [0.99815595]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4410/10000 Loss (MSE):  train=1.5276987552642822
# Epoch: 4420/10000 Loss (MSE):  train=1.5275838375091553
# Epoch: 4430/10000 Loss (MSE):  train=1.527470588684082
# Epoch: 4440/10000 Loss (MSE):  train=1.527357578277588
# Epoch: 4450/10000 Loss (MSE):  train=1.5272436141967773
# Epoch: 4460/10000 Loss (MSE):  train=1.5271323919296265
# Epoch: 4470/10000 Loss (MSE):  train=1.5270187854766846
# Epoch: 4480/10000 Loss (MSE):  train=1.526906967163086
# Epoch: 4490/10000 Loss (MSE):  train=1.526794672012329
# Epoch: 4500/10000 Loss (MSE):  train=1.5266830921173096
# gammaaaaa:  [[0.99816775]
#  [0.99816775]
#  [0.99816775]
#  [0.99816775]
#  [0.99816775]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4510/10000 Loss (MSE):  train=1.5265721082687378
# Epoch: 4520/10000 Loss (MSE):  train=1.5264610052108765
# Epoch: 4530/10000 Loss (MSE):  train=1.5263497829437256
# Epoch: 4540/10000 Loss (MSE):  train=1.5262380838394165
# Epoch: 4550/10000 Loss (MSE):  train=1.5261276960372925
# Epoch: 4560/10000 Loss (MSE):  train=1.5260154008865356
# Epoch: 4570/10000 Loss (MSE):  train=1.5259045362472534
# Epoch: 4580/10000 Loss (MSE):  train=1.525794506072998
# Epoch: 4590/10000 Loss (MSE):  train=1.5256834030151367
# Epoch: 4600/10000 Loss (MSE):  train=1.5255720615386963
# gammaaaaa:  [[0.9981813 ]
#  [0.9981813 ]
#  [0.9981813 ]
#  [0.9981813 ]
#  [0.99818134]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4610/10000 Loss (MSE):  train=1.5254616737365723
# Epoch: 4620/10000 Loss (MSE):  train=1.5253502130508423
# Epoch: 4630/10000 Loss (MSE):  train=1.5252389907836914
# Epoch: 4640/10000 Loss (MSE):  train=1.5251286029815674
# Epoch: 4650/10000 Loss (MSE):  train=1.5250180959701538
# Epoch: 4660/10000 Loss (MSE):  train=1.5249079465866089
# Epoch: 4670/10000 Loss (MSE):  train=1.5247970819473267
# Epoch: 4680/10000 Loss (MSE):  train=1.5246860980987549
# Epoch: 4690/10000 Loss (MSE):  train=1.5245749950408936
# Epoch: 4700/10000 Loss (MSE):  train=1.5244638919830322
# gammaaaaa:  [[0.99818707]
#  [0.99818707]
#  [0.99818707]
#  [0.99818707]
#  [0.998187  ]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4710/10000 Loss (MSE):  train=1.5243535041809082
# Epoch: 4720/10000 Loss (MSE):  train=1.5242434740066528
# Epoch: 4730/10000 Loss (MSE):  train=1.5241317749023438
# Epoch: 4740/10000 Loss (MSE):  train=1.5240216255187988
# Epoch: 4750/10000 Loss (MSE):  train=1.5239105224609375
# Epoch: 4760/10000 Loss (MSE):  train=1.5238006114959717
# Epoch: 4770/10000 Loss (MSE):  train=1.5236896276474
# Epoch: 4780/10000 Loss (MSE):  train=1.5235788822174072
# Epoch: 4790/10000 Loss (MSE):  train=1.523468017578125
# Epoch: 4800/10000 Loss (MSE):  train=1.523357629776001
# gammaaaaa:  [[0.998187]
#  [0.998187]
#  [0.998187]
#  [0.998187]
#  [0.998187]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4810/10000 Loss (MSE):  train=1.5232466459274292
# Epoch: 4820/10000 Loss (MSE):  train=1.5231356620788574
# Epoch: 4830/10000 Loss (MSE):  train=1.5230246782302856
# Epoch: 4840/10000 Loss (MSE):  train=1.522913932800293
# Epoch: 4850/10000 Loss (MSE):  train=1.522802472114563
# Epoch: 4860/10000 Loss (MSE):  train=1.5226905345916748
# Epoch: 4870/10000 Loss (MSE):  train=1.5225791931152344
# Epoch: 4880/10000 Loss (MSE):  train=1.5224664211273193
# Epoch: 4890/10000 Loss (MSE):  train=1.522351622581482
# Epoch: 4900/10000 Loss (MSE):  train=1.5222364664077759
# gammaaaaa:  [[0.9981726]
#  [0.9981726]
#  [0.9981726]
#  [0.9981726]
#  [0.9981724]]
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/loss_array.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/fgnode_trained_model_low.dil ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/05-17-2023_09-43-09/training_loss.png ===
# Epoch: 4910/10000 Loss (MSE):  train=1.5221027135849
# Epoch: 4920/10000 Loss (MSE):  train=1.5219240188598633
# Epoch: 4930/10000 Loss (MSE):  train=1.5217710733413696
# Epoch: 4940/10000 Loss (MSE):  train=1.5216283798217773
# Epoch: 4950/10000 Loss (MSE):  train=1.521491527557373
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 67
#      65 for data in zip(bRs_in, bRs_out):
#      66     optimizer_step += 1
# ---> 67     opt_state, params, l_ = step(
#      68         optimizer_step, (opt_state, params, 0), *data)
#      69     l += l_
#      70     count+=1
#
# File ~/GitHub/BGNODE_scratch/.venv_jaxbrow/lib/python3.9/site-packages/jax/example_libraries/optimizers.py:120, in <lambda>(data, xs)
#     108 # The implementation here basically works by flattening pytrees. There are two
#     109 # levels of pytrees to think about: the pytree of params, which we can think of
#     110 # as defining an "outer pytree", and a pytree produced by applying init_fun to
#     111 # each leaf of the params pytree, which we can think of as the "inner pytrees".
#     112 # Since pytrees can be flattened, that structure is isomorphic to a list of
#     113 # lists (with no further nesting).
#     115 OptimizerState = namedtuple("OptimizerState",
#     116                             ["packed_state", "tree_def", "subtree_defs"])
#     117 register_pytree_node(
#     118     OptimizerState,
#     119     lambda xs: ((xs.packed_state,), (xs.tree_def, xs.subtree_defs)),
# --> 120     lambda data, xs: OptimizerState(xs[0], data[0], data[1]))  # type: ignore[index]
#     123 Array = Any
#     124 Params = Any  # Parameters are arbitrary nests of `jnp.ndarrays`.
#
# KeyboardInterrupt:

# %%
# params, _ = loadfile(f"fgnode_trained_model_low.dil", verbose=True)

# %%
rname=False

# PSYS = f"a-{N}-Spring-data-brownian_EM"
# TAG = f"3BFGN"
# out_dir = f"../results"

def _filename(name, tag=TAG):
    rstring = randfilename if (rname and (tag != "data")) else (
        "0" if (tag == "data") or (withdata == None) else f"0_{withdata}")
    filename_prefix = f"{out_dir}/{PSYS}-{tag}/{rstring}/"
    file = f"{filename_prefix}/{name}"
    os.makedirs(os.path.dirname(file), exist_ok=True)
    filename = f"{filename_prefix}/{name}".replace("//", "/")
    print("===", filename, "===")
    return filename

def OUT(f):
    @wraps(f)
    def func(file, *args, tag=TAG, **kwargs):
        return f(_filename(file, tag=tag), *args, **kwargs)
    return func

loadmodel = OUT(src.models.loadmodel)
savemodel = OUT(src.models.savemodel)

loadfile = OUT(src.io.loadfile)
savefile = OUT(src.io.savefile)
save_ovito = OUT(src.io.save_ovito)

# %%
params, _ = loadfile(f"fgnode_trained_model_low.dil", verbose=True)
# Out:
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/fgnode_trained_model_low.dil ===
# Loading ../results/a-5-Spring-data-brownian_EM-3BFGN/0/fgnode_trained_model_low.dil

# %%
gamma_fn_model(params)
# Out:
# Array([[0.99778473],
#        [0.99778473],
#        [0.99778473],
#        [0.99778473],
#        [0.9977848 ]], dtype=float32)

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt

spring_constant = 1.0
length_constant = 1.0
gamma_orig = jnp.ones(jnp.unique(species).shape)
stride = 1
runs=100

def SPRING(x, stiffness=1.0, length=1.0):
    x_ = jnp.linalg.norm(x, keepdims=True)
    return 0.5*stiffness*(x_ - length)**2

def pot_energy_orig(x):
    dr = x[senders, :] - x[receivers, :]
    return vmap(partial(SPRING, stiffness=spring_constant, length=length_constant))(dr).sum()

def force_fn_orig(R, params):
    return -grad(pot_energy_orig)(R)


def get_forward_sim(params = None, force_fn = None, gamma = None, runs=10):
        @jit
        def fn(R,key):
            return predition_brow(R, params, force_fn, shift, dt, kT, masses, gamma = gamma, stride=stride, runs=runs, key=key)
        return fn

gamma_model = gamma_fn_model(params)

sim_orig = get_forward_sim(params=None,force_fn=force_fn_orig, gamma=gamma_orig,runs=runs)
sim_model = get_forward_sim(params=params,force_fn=force_fn_model, gamma=gamma_model,runs=runs)

# %%
import time

plotthings = True
rng_key = random.PRNGKey(0)
maxtraj = 100

_gamma = gamma_fn_model(params)
nexp = {
        "dz_actual": [],
        "dz_pred": [],
        "z_actual": [],
        "z_pred": [],
        "_gamma": [_gamma],
        "simulation_time":[],
        }

trajectories = []
for ind in range(maxtraj):
    print(f"Simulating trajectory {ind}/{maxtraj} ...")
    R, _ = chain(N)[:2]
    for rand in range(10):
        rng_key, subkey = random.split(rng_key)
        actual_traj = sim_orig(R,(ind+13)*subkey)
        rng_key, subkey = random.split(rng_key)
        start = time.time()
        pred_traj = sim_model(R, (ind+13)*subkey)
        end = time.time()
        nexp["simulation_time"] += [end-start]
        
        nexp["dz_actual"] += [actual_traj.position-R]
        nexp["dz_pred"] += [pred_traj.position-R]
        
        nexp["z_actual"] += [actual_traj.position]
        nexp["z_pred"] += [pred_traj.position]
        
        if save_ovito:
            if ind<1 and rand<1:
                save_ovito(f"actual_{ind}_{rand}.xyz", [state for state in BrownianStates(actual_traj)], lattice="")
                save_ovito(f"pred_{ind}_{rand}.xyz", [state for state in BrownianStates(pred_traj)], lattice="")
        
        trajectories += [(actual_traj, pred_traj)]
        if ind%10==0:
            savefile("trajectories.pkl", trajectories)

savefile(f"error_parameter.pkl", nexp)
savefile("trajectories.pkl", trajectories)
# Out:
# Simulating trajectory 0/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_0.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_0.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_0.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_0.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_1.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_1.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_1.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_1.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_2.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_2.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_2.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_2.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_3.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_3.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_3.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_3.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_4.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_0_4.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_4.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_0_4.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 1/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_0.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_0.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_0.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_0.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_1.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_1.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_1.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_1.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_2.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_2.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_2.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_2.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_3.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_3.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_3.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_3.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_4.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/actual_1_4.xyz
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_4.xyz ===
# Saving ovito file: ../results/a-5-Spring-data-brownian_EM-3BFGN/0/pred_1_4.xyz
# Simulating trajectory 2/100 ...
# Simulating trajectory 3/100 ...
# Simulating trajectory 4/100 ...
# Simulating trajectory 5/100 ...
# Simulating trajectory 6/100 ...
# Simulating trajectory 7/100 ...
# Simulating trajectory 8/100 ...
# Simulating trajectory 9/100 ...
# Simulating trajectory 10/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 11/100 ...
# Simulating trajectory 12/100 ...
# Simulating trajectory 13/100 ...
# Simulating trajectory 14/100 ...
# Simulating trajectory 15/100 ...
# Simulating trajectory 16/100 ...
# Simulating trajectory 17/100 ...
# Simulating trajectory 18/100 ...
# Simulating trajectory 19/100 ...
# Simulating trajectory 20/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 21/100 ...
# Simulating trajectory 22/100 ...
# Simulating trajectory 23/100 ...
# Simulating trajectory 24/100 ...
# Simulating trajectory 25/100 ...
# Simulating trajectory 26/100 ...
# Simulating trajectory 27/100 ...
# Simulating trajectory 28/100 ...
# Simulating trajectory 29/100 ...
# Simulating trajectory 30/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 31/100 ...
# Simulating trajectory 32/100 ...
# Simulating trajectory 33/100 ...
# Simulating trajectory 34/100 ...
# Simulating trajectory 35/100 ...
# Simulating trajectory 36/100 ...
# Simulating trajectory 37/100 ...
# Simulating trajectory 38/100 ...
# Simulating trajectory 39/100 ...
# Simulating trajectory 40/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 41/100 ...
# Simulating trajectory 42/100 ...
# Simulating trajectory 43/100 ...
# Simulating trajectory 44/100 ...
# Simulating trajectory 45/100 ...
# Simulating trajectory 46/100 ...
# Simulating trajectory 47/100 ...
# Simulating trajectory 48/100 ...
# Simulating trajectory 49/100 ...
# Simulating trajectory 50/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 51/100 ...
# Simulating trajectory 52/100 ...
# Simulating trajectory 53/100 ...
# Simulating trajectory 54/100 ...
# Simulating trajectory 55/100 ...
# Simulating trajectory 56/100 ...
# Simulating trajectory 57/100 ...
# Simulating trajectory 58/100 ...
# Simulating trajectory 59/100 ...
# Simulating trajectory 60/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 61/100 ...
# Simulating trajectory 62/100 ...
# Simulating trajectory 63/100 ...
# Simulating trajectory 64/100 ...
# Simulating trajectory 65/100 ...
# Simulating trajectory 66/100 ...
# Simulating trajectory 67/100 ...
# Simulating trajectory 68/100 ...
# Simulating trajectory 69/100 ...
# Simulating trajectory 70/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 71/100 ...
# Simulating trajectory 72/100 ...
# Simulating trajectory 73/100 ...
# Simulating trajectory 74/100 ...
# Simulating trajectory 75/100 ...
# Simulating trajectory 76/100 ...
# Simulating trajectory 77/100 ...
# Simulating trajectory 78/100 ...
# Simulating trajectory 79/100 ...
# Simulating trajectory 80/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 81/100 ...
# Simulating trajectory 82/100 ...
# Simulating trajectory 83/100 ...
# Simulating trajectory 84/100 ...
# Simulating trajectory 85/100 ...
# Simulating trajectory 86/100 ...
# Simulating trajectory 87/100 ...
# Simulating trajectory 88/100 ...
# Simulating trajectory 89/100 ...
# Simulating trajectory 90/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
# Simulating trajectory 91/100 ...
# Simulating trajectory 92/100 ...
# Simulating trajectory 93/100 ...
# Simulating trajectory 94/100 ...
# Simulating trajectory 95/100 ...
# Simulating trajectory 96/100 ...
# Simulating trajectory 97/100 ...
# Simulating trajectory 98/100 ...
# Simulating trajectory 99/100 ...
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/error_parameter.pkl ===
# === ../results/a-5-Spring-data-brownian_EM-3BFGN/0/trajectories.pkl ===
